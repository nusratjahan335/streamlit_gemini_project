# %% [markdown]
# <a href="https://colab.research.google.com/github/nusratjahan335/streamlit_gemini_project/blob/main/basic_of_tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# creating tensor

# %%
import torch
print(torch.__version__)

# %%
if torch.cuda.is_available():
    print("GPU is available!")
    print(f"Device Name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is NOT available. Running on CPU.")

# %%
torch.zeros(2,3)

# %%
torch.ones(2,3)

# %%
torch.rand(2,3)

# %%
torch.manual_seed(100)
torch.rand(2,3)

# %%
torch.tensor([[1,2,3],[4,5,6]])

# %%
torch.eye(5)

# %%
torch.arange(0,10,2)

# %%
torch.linspace(1,10,8)

# %% [markdown]
# tensor shape

# %%
x = torch.tensor([[1,2,3],[4,5,6]])

x.shape

# %%
torch.zeros_like(x)

# %%
torch.rand_like(x,dtype=torch.float32)

# %% [markdown]
# Data Type

# %%
x.dtype

# %%
torch.tensor([1.0,5.0,3.0], dtype=torch.int32)

# %%
x = x.to(torch.float32)
x

# %%
x.dtype

# %% [markdown]
# Mathematical Operations

# %%
X = torch.tensor([[1,2,3] , [4,5,6]])
X

# %%
X+2

# %%
X-2

# %%
X*3

# %%
X/3

# %%
#Floor
x= X*100
x

# %%
x // 3

# %% [markdown]
# Element wise operations

# %%
a = torch.rand(3,4)
b = torch.rand(3,4)

# %%
a

# %%
b

# %%
a+b

# %%
a*b

# %%
a-b

# %%
a**b

# %%
c = torch.tensor([-2,-3,-4,-5])
torch.abs(c)

# %%
c = torch.tensor([2,3,4,5])
torch.neg(c)

# %%
d = torch.tensor([1.3,4.5,3.5,5.1])

# %%
torch.round(d)

# %%
torch.ceil(d)

# %%
e = torch.tensor([200,300,400,500])
torch.clamp(e, min=4, max = 10)

# %% [markdown]
# Reduction operation

# %%
p = torch.randint(size=(2,3), low= 0 , high = 10 , dtype = torch.float32 )

# %%
p

# %%
torch.sum(p)

# %%
torch.sum(p , dim=0)

# %%
torch.sum(p , dim=1)

# %%
torch.mean(p)

# %%
torch.median(p, dim =1)

# %%
torch.min(p)

# %%
torch.max(p)

# %%
torch.prod(p)

# %%
torch.std(p)

# %%
torch.var(p)

# %%
torch.argmin(p)

# %%
torch.argmax(p)

# %% [markdown]
# Matrix operations

# %%
f = torch.randint(size=(2,3), low=0,high = 10 )
g = torch.randint(size=(3,2), low=0,high = 10 )

# %%
f

# %%
g

# %%
torch.matmul(f,g)

# %%
#dot product

vector1 = torch.tensor([1,2])
vector2 = torch.tensor([3,4])

# %%
torch.dot(vector1,vector2)

# %%
f

# %%
torch.transpose(f,0,1)

# %%
h = torch.randint(size = (3,3), low=0, high = 10,dtype=torch.float32)

# %%
torch.det(h)

# %%
torch.inverse(h)

# %% [markdown]
# Comperision operation

# %%
i = torch.randint(size=(2,3), low= 0 , high = 10)
j = torch.randint(size=(2,3), low= 0 , high = 10)

# %%
i

# %%
j

# %%
#greater then
i>j

# %%
#less then
i<j

# %%
#equal to
i==j

# %%
# not equal to
i != j

# %% [markdown]
# Special function

# %%
k = torch.tensor([10,20,30])

# %%
torch.log(k)

# %%
torch.exp(k)

# %%
torch.sqrt(k)

# %%
torch.sigmoid(k)

# %%
torch.relu(k)

# %%
torch.softmax(k.float() , dim =0)

# %% [markdown]
# Inplace operation

# %%
a = torch.tensor([1,2,3])
a

# %%
m = torch.rand(2,3)
n = torch.rand(2,3)

# %%
m.add_(n)

# %%
torch.relu(m)

# %% [markdown]
# copying a tensor

# %%
a = torch.tensor([1,2,3,4,5])

# %%
b = a.clone()

# %%
b

# %%
id(a)
